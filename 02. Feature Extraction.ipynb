# %% [markdown]
# ## Importing necessary libs

# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json

# %% [markdown]
# ## Reading time-series data

# %%
df = pd.read_csv("preprocessed_ts.csv")

# %%
df.head()
# Out:
#   userID_anonymized       model operating_system  wifi_state  session_no  \
# 0     be725f9b-33c5  iPhone12,1       iOS 14.0.1           1           1
# 1     dd5ef583-258b  iPhone12,1         iOS 14.2           0          13
# 2     be725f9b-33c5  iPhone12,1       iOS 14.0.1           1           1
# 3     fb8331dd-f7f7  iPhone11,8         iOS 14.2           1           3
# 4     64dea955-8f14  iPhone11,6         iOS 14.2           1           1
#
#    event_delay                eventType      duration  level  progress  \
# 0          1.0  interstitial_impression  0.000000e+00      0         0
# 1        195.0        banner_impression  0.000000e+00      0         0
# 2          2.0              level_event  1.606707e+09     25        10
# 3         45.0        banner_impression  0.000000e+00      0         0
# 4          3.0        banner_impression  0.000000e+00      0         0
#
#    play_count  status  revenue  totalrevenue
# 0           0       0  0.03500      0.036200
# 1           0       0  0.00030      0.460578
# 2          10       1  0.00000      0.036200
# 3           0       0  0.00030      1.161082
# 4           0       0  0.00015      0.408266

# %% [markdown]
# # Feature Extraction
#
# I will extract these properties for each unique user:
#
# - Total interstitial impression count
# - Total banner impression count
# - Total rewarded impression count
# - Total level event count
# - Last interstitial (delay_hour format)
# - Last banner (delay_hour format)
# - Last rewarded (delay_hour format)
# - Last level event  (delay_hour format)
#
# and mean and stds of the revenues of:
# - Interstitials
# - Banners
# - Rewardeds

# %%
# Extracting means
means = df.groupby(['userID_anonymized', 'eventType'])['revenue'].mean().unstack(['eventType'], fill_value=0)\
.add_prefix('mean_revenue_').rename_axis(None, axis=1).reset_index().fillna(0).set_index("userID_anonymized")

# Extracting stds
stds = df.groupby(['userID_anonymized', 'eventType'])['revenue'].std().unstack(['eventType'], fill_value=0)\
.add_prefix('std_revenue_').rename_axis(None, axis=1).reset_index().fillna(0).set_index("userID_anonymized")

# Extracting total counts
totals = df.groupby(['userID_anonymized', 'eventType'])['revenue'].count().unstack(['eventType'], fill_value=0)\
.add_prefix('total_count_').rename_axis(None, axis=1).reset_index().fillna(0).set_index("userID_anonymized")

# Extracting last times
last_times = df.groupby(['userID_anonymized', 'eventType'])['event_delay'].max().unstack(['eventType'], fill_value=0)\
.add_prefix('last_time_').rename_axis(None, axis=1).reset_index().fillna(0).set_index("userID_anonymized")

# %% [markdown]
# ### Concatenating extracted features

# %%
concatted_df = pd.concat([means, stds, totals, last_times], axis=1, join="inner").rename_axis(None, axis=1).reset_index()

# %% [markdown]
# ### Merging with original data

# %%
concatted_df['model'] = df.groupby(['userID_anonymized'])['model'].min().values
concatted_df['operating_system'] = df.groupby(['userID_anonymized'])['operating_system'].min().values

# mean encoding for wi-fi
concatted_df['mean_wifi_state'] = df.groupby(['userID_anonymized'])['wifi_state'].mean().values

# to get last session number
concatted_df['last_session_no'] = df.groupby(['userID_anonymized'])['session_no'].max().values

# to get last played level
concatted_df['last_level'] = df.groupby(['userID_anonymized'])['level'].max().values

# to get lifetime-revenue
concatted_df['totalrevenue'] = df.groupby(['userID_anonymized'])['totalrevenue'].max().values

# %%
concatted_df.head()
# Out:
#   userID_anonymized  mean_revenue_banner_impression  \
# 0     00081f8b-253d                        0.000400
# 1     000ab112-2616                        0.000375
# 2     002ff54d-8749                        0.000669
# 3     0030d0af-2830                        0.000416
# 4     00441340-5d9c                        0.000537
#
#    mean_revenue_interstitial_impression  mean_revenue_level_event  \
# 0                              0.030000                       0.0
# 1                              0.030000                       0.0
# 2                              0.027517                       0.0
# 3                              0.022920                       0.0
# 4                              0.030000                       0.0
#
#    mean_revenue_rewarded_impression  std_revenue_banner_impression  \
# 0                              0.00                       0.000000
# 1                              0.00                       0.000318
# 2                              0.04                       0.000962
# 3                              0.04                       0.000184
# 4                              0.00                       0.000096
#
#    std_revenue_interstitial_impression  std_revenue_level_event  \
# 0                             0.000000                      0.0
# 1                             0.000000                      0.0
# 2                             0.005541                      0.0
# 3                             0.005129                      0.0
# 4                             0.003536                      0.0
#
#    std_revenue_rewarded_impression  total_count_banner_impression  ...  \
# 0                              0.0                              6  ...
# 1                              0.0                              2  ...
# 2                              0.0                            118  ...
# 3                              0.0                             82  ...
# 4                              0.0                             16  ...
#
#    last_time_banner_impression  last_time_interstitial_impression  \
# 0                         13.0                                2.0
# 1                          0.0                                0.0
# 2                       4078.0                             4076.0
# 3                       5137.0                             5136.0
# 4                       2368.0                             2035.0
#
#    last_time_level_event  last_time_rewarded_impression       model  \
# 0                   14.0                            0.0   iPhone8,2
# 1                    0.0                            0.0  iPhone12,1
# 2                 4078.0                         1621.0  iPhone12,8
# 3                 5137.0                          763.0   iPhone9,3
# 4                 2369.0                            0.0  iPhone10,2
#
#    operating_system  mean_wifi_state last_session_no last_level  totalrevenue
# 0        iOS 14.0.1         1.000000               3         65      0.032400
# 1          iOS 14.2         1.000000               1          4      0.030750
# 2          iOS 14.1         0.814159               8       1004      1.211006
# 3          iOS 13.7         1.000000               5       1003      0.881707
# 4          iOS 14.2         1.000000               4         67      0.184700
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Saving feature-engineered data

# %%
concatted_df.to_csv('fe_data.csv', index=False)
